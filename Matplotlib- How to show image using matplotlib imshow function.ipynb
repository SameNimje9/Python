# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img=mpimg.imread("pie_char.png")

# %%
img
# Out:
# array([[[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        ...,
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]],
#
#        [[0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         ...,
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ],
#         [0.       , 0.5019608, 0.       , 1.       ]]], dtype=float32)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (4000, 6000, 4)

# %%
img.ndim
# Out:
# 3

# %%
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(img)
plt.colorbar()
plt.show()

# %%
single_channel=img[:,:,2]
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(single_channel,cmap="hot")
plt.colorbar()
plt.show()

# %%
 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

# %%
img2= mpimg.imread("C:\\Users\\NIMJESX\\Pictures\\Saved Pictures\\Sam3.jpg")
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(img2)
plt.colorbar()
plt.show()

# %%
single_channel2_img = img2[:,:,1]
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(single_channel2_img,cmap="hot")
plt.colorbar()
plt.savefig("model_hot.png")
plt.show()

# %%
single_channel2_img = img2[:,:,1]
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(single_channel2_img,cmap="nipy_spectral")
plt.colorbar()
plt.savefig("model_hot.png")
plt.show()

# %%
cmap = """'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r"""

cmap_name_list = cmap.split(sep=",")

# %%
cmap_name_list
# Out:
# ["'Accent'",
#  " 'Accent_r'",
#  " 'Blues'",
#  " 'Blues_r'",
#  " 'BrBG'",
#  " 'BrBG_r'",
#  " 'BuGn'",
#  " 'BuGn_r'",
#  " 'BuPu'",
#  " 'BuPu_r'",
#  " 'CMRmap'",
#  " 'CMRmap_r'",
#  " 'Dark2'",
#  " 'Dark2_r'",
#  " 'GnBu'",
#  " 'GnBu_r'",
#  " 'Greens'",
#  " 'Greens_r'",
#  " 'Greys'",
#  " 'Greys_r'",
#  " 'OrRd'",
#  " 'OrRd_r'",
#  " 'Oranges'",
#  " 'Oranges_r'",
#  " 'PRGn'",
#  " 'PRGn_r'",
#  " 'Paired'",
#  " 'Paired_r'",
#  " 'Pastel1'",
#  " 'Pastel1_r'",
#  " 'Pastel2'",
#  " 'Pastel2_r'",
#  " 'PiYG'",
#  " 'PiYG_r'",
#  " 'PuBu'",
#  " 'PuBuGn'",
#  " 'PuBuGn_r'",
#  " 'PuBu_r'",
#  " 'PuOr'",
#  " 'PuOr_r'",
#  " 'PuRd'",
#  " 'PuRd_r'",
#  " 'Purples'",
#  " 'Purples_r'",
#  " 'RdBu'",
#  " 'RdBu_r'",
#  " 'RdGy'",
#  " 'RdGy_r'",
#  " 'RdPu'",
#  " 'RdPu_r'",
#  " 'RdYlBu'",
#  " 'RdYlBu_r'",
#  " 'RdYlGn'",
#  " 'RdYlGn_r'",
#  " 'Reds'",
#  " 'Reds_r'",
#  " 'Set1'",
#  " 'Set1_r'",
#  " 'Set2'",
#  " 'Set2_r'",
#  " 'Set3'",
#  " 'Set3_r'",
#  " 'Spectral'",
#  " 'Spectral_r'",
#  " 'Wistia'",
#  " 'Wistia_r'",
#  " 'YlGn'",
#  " 'YlGnBu'",
#  " 'YlGnBu_r'",
#  " 'YlGn_r'",
#  " 'YlOrBr'",
#  " 'YlOrBr_r'",
#  " 'YlOrRd'",
#  " 'YlOrRd_r'",
#  " 'afmhot'",
#  " 'afmhot_r'",
#  " 'autumn'",
#  " 'autumn_r'",
#  " 'binary'",
#  " 'binary_r'",
#  " 'bone'",
#  " 'bone_r'",
#  " 'brg'",
#  " 'brg_r'",
#  " 'bwr'",
#  " 'bwr_r'",
#  " 'cividis'",
#  " 'cividis_r'",
#  " 'cool'",
#  " 'cool_r'",
#  " 'coolwarm'",
#  " 'coolwarm_r'",
#  " 'copper'",
#  " 'copper_r'",
#  " 'cubehelix'",
#  " 'cubehelix_r'",
#  " 'flag'",
#  " 'flag_r'",
#  " 'gist_earth'",
#  " 'gist_earth_r'",
#  " 'gist_gray'",
#  " 'gist_gray_r'",
#  " 'gist_heat'",
#  " 'gist_heat_r'",
#  " 'gist_ncar'",
#  " 'gist_ncar_r'",
#  " 'gist_rainbow'",
#  " 'gist_rainbow_r'",
#  " 'gist_stern'",
#  " 'gist_stern_r'",
#  " 'gist_yarg'",
#  " 'gist_yarg_r'",
#  " 'gnuplot'",
#  " 'gnuplot2'",
#  " 'gnuplot2_r'",
#  " 'gnuplot_r'",
#  " 'gray'",
#  " 'gray_r'",
#  " 'hot'",
#  " 'hot_r'",
#  " 'hsv'",
#  " 'hsv_r'",
#  " 'inferno'",
#  " 'inferno_r'",
#  " 'jet'",
#  " 'jet_r'",
#  " 'magma'",
#  " 'magma_r'",
#  " 'nipy_spectral'",
#  " 'nipy_spectral_r'",
#  " 'ocean'",
#  " 'ocean_r'",
#  " 'pink'",
#  " 'pink_r'",
#  " 'plasma'",
#  " 'plasma_r'",
#  " 'prism'",
#  " 'prism_r'",
#  " 'rainbow'",
#  " 'rainbow_r'",
#  " 'seismic'",
#  " 'seismic_r'",
#  " 'spring'",
#  " 'spring_r'",
#  " 'summer'",
#  " 'summer_r'",
#  " 'tab10'",
#  " 'tab10_r'",
#  " 'tab20'",
#  " 'tab20_r'",
#  " 'tab20b'",
#  " 'tab20b_r'",
#  " 'tab20c'",
#  " 'tab20c_r'",
#  " 'terrain'",
#  " 'terrain_r'",
#  " 'turbo'",
#  " 'turbo_r'",
#  " 'twilight'",
#  " 'twilight_r'",
#  " 'twilight_shifted'",
#  " 'twilight_shifted_r'",
#  " 'viridis'",
#  " 'viridis_r'",
#  " 'winter'",
#  " 'winter_r"]

# %%
save_image_addr_name = []
for i in range(len(cmap_name_list)):
    cmap_str = cmap_name_list[i]
    save_image_addr_name.append("C:\\Users\\NIMJESX\\Documents\\My Folder\\Python\\Images"+"girl_" + cmap_name_list[i] + ".png")
    print(save_image_addr_name[i])
# Out:
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_'Accent'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Accent_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Blues'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Blues_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'BrBG'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'BrBG_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'BuGn'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'BuGn_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'BuPu'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'BuPu_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'CMRmap'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'CMRmap_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Dark2'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Dark2_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'GnBu'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'GnBu_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Greens'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Greens_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Greys'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Greys_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'OrRd'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'OrRd_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Oranges'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Oranges_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PRGn'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PRGn_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Paired'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Paired_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Pastel1'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Pastel1_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Pastel2'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Pastel2_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PiYG'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PiYG_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuBu'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuBuGn'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuBuGn_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuBu_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuOr'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuOr_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuRd'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'PuRd_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Purples'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Purples_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdBu'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdBu_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdGy'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdGy_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdPu'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdPu_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdYlBu'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdYlBu_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdYlGn'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'RdYlGn_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Reds'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Reds_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Set1'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Set1_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Set2'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Set2_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Set3'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Set3_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Spectral'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Spectral_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Wistia'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'Wistia_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlGn'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlGnBu'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlGnBu_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlGn_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlOrBr'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlOrBr_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlOrRd'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'YlOrRd_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'afmhot'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'afmhot_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'autumn'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'autumn_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'binary'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'binary_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'bone'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'bone_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'brg'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'brg_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'bwr'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'bwr_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'cividis'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'cividis_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'cool'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'cool_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'coolwarm'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'coolwarm_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'copper'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'copper_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'cubehelix'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'cubehelix_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'flag'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'flag_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_earth'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_earth_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_gray'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_gray_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_heat'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_heat_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_ncar'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_ncar_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_rainbow'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_rainbow_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_stern'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_stern_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_yarg'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gist_yarg_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gnuplot'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gnuplot2'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gnuplot2_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gnuplot_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gray'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'gray_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'hot'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'hot_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'hsv'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'hsv_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'inferno'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'inferno_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'jet'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'jet_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'magma'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'magma_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'nipy_spectral'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'nipy_spectral_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'ocean'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'ocean_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'pink'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'pink_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'plasma'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'plasma_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'prism'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'prism_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'rainbow'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'rainbow_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'seismic'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'seismic_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'spring'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'spring_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'summer'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'summer_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab10'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab10_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab20'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab20_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab20b'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab20b_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab20c'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'tab20c_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'terrain'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'terrain_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'turbo'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'turbo_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'twilight'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'twilight_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'twilight_shifted'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'twilight_shifted_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'viridis'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'viridis_r'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'winter'.png
# C:\Users\NIMJESX\Documents\My Folder\Python\Imagesgirl_ 'winter_r.png
