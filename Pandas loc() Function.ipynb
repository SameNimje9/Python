# %% [markdown]
# Loc =Access a group of rows & columns by labels or a boolean array
# iloc=Integer location-based indexing

# %%
import pandas as pd

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\student_1.csv')
df
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             62             23       94  28.1
# 4             0      137             60             35      168  43.1
# 5             5      116             58              0        0  25.6
# 6             3       78             56             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
#
#           date
# 0   23-10-2025
# 1   23-10-2026
# ...

# %%
df.loc[0]
# Out:
# Pregnancies               6
# Glucose                 148
# BloodPressure            72
# SkinThickness            35
# Insulin                   0
# BMI                    33.6
# date             23-10-2025
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# Pregnancies               0
# Glucose                 137
# BloodPressure            60
# SkinThickness            35
# Insulin                 168
# BMI                    43.1
# date             23-10-2029
# Name: 4, dtype: object

# %%
df.loc[[0,1]]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#          date
# 0  23-10-2025
# 1  23-10-2026

# %%
df.loc[[2,5]]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2            8      183             64              0        0  23.3
# 5            5      116             58              0        0  25.6
#
#          date
# 2  23-10-2027
# 5  23-10-2030

# %%
df.loc[4,'Glucose']
# Out:
# 137

# %%
df.loc[0:3,'Glucose']
# Out:
# 0    148
# 1     85
# 2    183
# 3     89
# Name: Glucose, dtype: int64

# %%
df.loc[0:2,'BMI']
# Out:
# 0    33.6
# 1    26.6
# 2    23.3
# Name: BMI, dtype: float64

# %%
df.loc[df['Glucose']>150]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2             8      183             64              0        0  23.3
# 8             2      197             70             45      543  30.5
# 11           10      168             74              0        0  38.0
#
#           date
# 2   23-10-2027
# 8   23-10-2033
# 11  23-10-2036

# %%
df.loc[df['Glucose']>150,['BMI']]
# Out:
#      BMI
# 2   23.3
# 8   30.5
# 11  38.0

# %%
df.iloc[0]
# Out:
# Pregnancies               6
# Glucose                 148
# BloodPressure            72
# SkinThickness            35
# Insulin                   0
# BMI                    33.6
# date             23-10-2025
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#          date
# 0  23-10-2025

# %%
df.iloc[:,0]
# Out:
# 0      6
# 1      1
# 2      8
# 3      1
# 4      0
# 5      5
# 6      3
# 7     10
# 8      2
# 9      8
# 10     4
# 11    10
# Name: Pregnancies, dtype: int64

# %%
df.iloc[[0,1]]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#          date
# 0  23-10-2025
# 1  23-10-2026

# %%
df.iloc[[True,False,True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-1c7ad5252202> in <module>
# ----> 1 df.iloc[[True,False,True]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1481         if com.is_bool_indexer(key):
#    1482             self._validate_key(key, axis)
# -> 1483             return self._getbool_axis(key, axis=axis)
#    1484
#    1485         # a list of integers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
# ...
