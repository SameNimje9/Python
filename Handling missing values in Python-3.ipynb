# %%
import pandas as pd

# %%
#dropna--asis,how,thresh,inplace

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune_5.csv')
df
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 4     5           Cencora    NaN                   NaN   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9          McKesson    MCK                 219.6  Health Care
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# ...

# %%
df.dropna()
# Out:
#    Rank      Company Ticker  ProfitsPercentChange       Sector  \
# 0     1      Walmart    WMT                  32.8    Retailing
# 6     7  Exxon Mobil    WMT                 -35.4       Energy
# 7     8     Alphabet  GOOGL                  23.0   Technology
# 8     9     McKesson    MCK                 219.6  Health Care
#
#                           Industry
# 0            General Merchandisers
# 6               Petroleum Refining
# 7  Internet Services and Retailing
# 8         Wholesalers: Health Care

# %%
df.dropna(axis=1)
# Out:
#    Rank           Company       Sector  \
# 0     1           Walmart    Retailing
# 1     2       Exxon Mobil    Retailing
# 2     3          Alphabet   Technology
# 3     4          McKesson  Health Care
# 4     5           Cencora   Financials
# 5     6  Costco Wholesale  Health Care
# 6     7       Exxon Mobil       Energy
# 7     8          Alphabet   Technology
# 8     9          McKesson  Health Care
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                  Wholesalers: Health Care

# %%
df.dropna(how='any')
# Out:
#    Rank      Company Ticker  ProfitsPercentChange       Sector  \
# 0     1      Walmart    WMT                  32.8    Retailing
# 6     7  Exxon Mobil    WMT                 -35.4       Energy
# 7     8     Alphabet  GOOGL                  23.0   Technology
# 8     9     McKesson    MCK                 219.6  Health Care
#
#                           Industry
# 0            General Merchandisers
# 6               Petroleum Refining
# 7  Internet Services and Retailing
# 8         Wholesalers: Health Care

# %%
df.dropna(axis = 1,how='any')
# Out:
#    Rank           Company       Sector  \
# 0     1           Walmart    Retailing
# 1     2       Exxon Mobil    Retailing
# 2     3          Alphabet   Technology
# 3     4          McKesson  Health Care
# 4     5           Cencora   Financials
# 5     6  Costco Wholesale  Health Care
# 6     7       Exxon Mobil       Energy
# 7     8          Alphabet   Technology
# 8     9          McKesson  Health Care
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                  Wholesalers: Health Care

# %%
df.dropna(how='all')
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 4     5           Cencora    NaN                   NaN   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9          McKesson    MCK                 219.6  Health Care
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune_5.csv')
df
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 4     5           Cencora    NaN                   NaN   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9               NaN    NaN                   NaN          NaN
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# ...

# %%
df.dropna(thresh=2)
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 4     5           Cencora    NaN                   NaN   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# ...

# %%
df.dropna(thresh=4)
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 4     5           Cencora    NaN                   NaN   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# ...

# %%
df.dropna(subset=['Rank'])
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 4     5           Cencora    NaN                   NaN   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9               NaN    NaN                   NaN          NaN
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# ...

# %%
df.dropna(subset=['Ticker'])
# Out:
#    Rank      Company Ticker  ProfitsPercentChange      Sector  \
# 0     1      Walmart    WMT                  32.8   Retailing
# 1     2  Exxon Mobil    WMT                   NaN   Retailing
# 6     7  Exxon Mobil    WMT                 -35.4      Energy
# 7     8     Alphabet  GOOGL                  23.0  Technology
#
#                           Industry
# 0            General Merchandisers
# 1  Internet Services and Retailing
# 6               Petroleum Refining
# 7  Internet Services and Retailing

# %%
df.dropna(subset=['ProfitsPercentChange'])
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
#
#                                    Industry
# 0                     General Merchandisers
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing

# %%
df.dropna(inplace=True)
df
# Out:
#    Rank      Company Ticker  ProfitsPercentChange      Sector  \
# 0     1      Walmart    WMT                  32.8   Retailing
# 6     7  Exxon Mobil    WMT                 -35.4      Energy
# 7     8     Alphabet  GOOGL                  23.0  Technology
#
#                           Industry
# 0            General Merchandisers
# 6               Petroleum Refining
# 7  Internet Services and Retailing
