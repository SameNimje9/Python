# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\googleplaystore.csv")

# %%
df.shape
# Out:
# (10841, 13)

# %%
df=pd.read_csv("C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\googleplaystore.csv",nrows=1000)
df.shape
# Out:
# (1000, 13)

# %%
df
# Out:
#                                                    App        Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 995                                     My Talking Pet   ENTERTAINMENT
# 996                                         Funny Pics   ENTERTAINMENT
# 997                                  Funny Quotes Free   ENTERTAINMENT
# 998                          LOL Pics (Funny Pictures)   ENTERTAINMENT
# 999                                       Meme Creator   ENTERTAINMENT
#
#      Rating  Reviews                Size     Installs  Type  Price  \
# ...

# %%
x=df["Rating"]
y=df["Reviews"]

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.title("Google play store apps Scatter plot")
plt.xlabel("Rating")
plt.ylabel("Reviews")
# Out:
# Text(0, 0.5, 'Reviews')

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y,c="r",marker="*",s=100,alpha=0.5,linewidth=10,edgecolor='g',verts="<")
plt.title("Google play store apps Scatter plot")
plt.xlabel("Rating")
plt.ylabel("Reviews")
# Out:
# <ipython-input-22-7485dd0539e9>:2: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   plt.scatter(x,y,c="r",marker="*",s=100,alpha=0.5,linewidth=10,edgecolor='g',verts="<")
# Text(0, 0.5, 'Reviews')

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y,c="r",s=100,alpha=0.5,linewidth=10,edgecolor='g',verts="<")
plt.title("Google play store apps Scatter plot")
plt.xlabel("Rating")
plt.ylabel("Reviews")
# Out:
# <ipython-input-24-2824ea9a92c6>:2: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   plt.scatter(x,y,c="r",s=100,alpha=0.5,linewidth=10,edgecolor='g',verts="<")
# Text(0, 0.5, 'Reviews')

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y,c="r",s=100,alpha=0.5,linewidth=10,edgecolor='g',verts="<")
plt.scatter(x,df["Installs"],c="b",s=100,alpha=0.5,linewidth=10,edgecolor='b',verts="<")
plt.title("Google play store apps Scatter plot")
plt.xlabel("Rating")
plt.ylabel("Reviews and Install")
# Out:
# <ipython-input-29-bd5b305b0af8>:2: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   plt.scatter(x,y,c="r",s=100,alpha=0.5,linewidth=10,edgecolor='g',verts="<")
# <ipython-input-29-bd5b305b0af8>:3: MatplotlibDeprecationWarning:
# The 'verts' parameter of scatter() was deprecated in Matplotlib 3.2 and will be removed two minor releases later. If any parameter follows 'verts', they should be passed as keyword, not positionally.
#   plt.scatter(x,df["Installs"],c="b",s=100,alpha=0.5,linewidth=10,edgecolor='b',verts="<")
# Text(0, 0.5, 'Reviews and Install')
