# %%
import pandas as pd

# %%
#ISNULL
#notnull

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
df.head(10)
# Out:
#    Rank      Company Ticker       Sector  \
# 0     1      Walmart    WMT    Retailing
# 1     2          NaN    NaN    Retailing
# 2     3          NaN    NaN   Technology
# 3     4          NaN    NaN  Health Care
# 4     5          NaN    NaN   Financials
# 5     6          NaN    NaN  Health Care
# 6     7  Exxon Mobil    WMT       Energy
# 7     8     Alphabet  GOOGL   Technology
# 8     9     McKesson    MCK  Health Care
# 9    10      Cencora    COR  Health Care
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# 3   Health Care: Insurance and Managed Care        yes             no
# 4  Insurance: Property and Casualty (Stock)        yes             no
# 5  Health Care: Pharmacy and Other Services        yes             no
# ...

# %%
df.head(10).isnull()
# Out:
#     Rank  Company  Ticker  Sector  Industry  Profitable  Founder_is_CEO  \
# 0  False    False   False   False     False       False           False
# 1  False     True    True   False     False       False           False
# 2  False     True    True   False     False       False           False
# 3  False     True    True   False     False       False           False
# 4  False     True    True   False     False       False           False
# 5  False     True    True   False     False       False           False
# 6  False    False   False   False     False       False           False
# 7  False    False   False   False     False       False           False
# 8  False    False   False   False     False       False           False
# 9  False    False   False   False     False       False           False
#
#    FemaleCEO  Growth_in_Jobs  Change_in_Rank  ...  Assets_M    CEO  Country  \
# 0      False           False           False  ...     False  False    False
# ...

# %%
df.head(10).isnull().sum()
# Out:
# Rank                             0
# Company                          5
# Ticker                           5
# Sector                           0
# Industry                         0
# Profitable                       0
# Founder_is_CEO                   0
# FemaleCEO                        0
# Growth_in_Jobs                   0
# Change_in_Rank                   0
# Gained_in_Rank                   0
# Dropped_in_Rank                  0
# Newcomer_to_the_Fortune500       0
# Global500                        0
# Worlds_Most_Admired_Companies    0
# Best_Companies_to_Work_For       0
# Number_of_employees              0
# MarketCap_March28_M              0
# Revenues_M                       0
# RevenuePercentChange             0
# Profits_M                        0
# ProfitsPercentChange             2
# Assets_M                         0
# CEO                              0
# Country                          0
# HeadquartersCity                 0
# HeadquartersState                0
# ...

# %%
df.head(10).isnull().sum().sum()
# Out:
# 12

# %%
df.head(10).notnull().sum().sum()
# Out:
# 308

# %%
# Series
import numpy as np
sr=pd.Series([1,2,3,np.nan,4,np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2
