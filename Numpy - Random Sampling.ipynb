# %%
import numpy as np
import random

# %%
np.random.random(1)
# Out:
# array([0.25917419])

# %%
np.random.random((3,3))
# Out:
# array([[0.5586398 , 0.5422657 , 0.88457633],
#        [0.043027  , 0.82937472, 0.37061178],
#        [0.81298888, 0.64452284, 0.01439769]])

# %%
np.random.randint(1,4)
# Out:
# 1

# %%
np.random.randint(1,4,(4,4))
# Out:
# array([[2, 2, 1, 3],
#        [1, 3, 2, 1],
#        [1, 3, 1, 3],
#        [2, 3, 2, 1]])

# %%
np.random.randint(1,4,(2,4,4))
# Out:
# array([[[3, 2, 3, 2],
#         [2, 3, 3, 2],
#         [3, 1, 2, 2],
#         [3, 3, 3, 2]],
#
#        [[1, 3, 3, 1],
#         [3, 3, 2, 2],
#         [1, 2, 2, 3],
#         [1, 1, 2, 2]]])

# %%
np.random.seed(10)
np.random.randint(1,4,(2,4,4))
# Out:
# array([[[2, 2, 1, 1],
#         [2, 1, 2, 2],
#         [1, 2, 2, 3],
#         [1, 2, 1, 3]],
#
#        [[1, 3, 1, 1],
#         [1, 3, 1, 3],
#         [3, 2, 1, 1],
#         [3, 2, 3, 2]]])

# %%
np.random.seed(10)
np.random.randint(1,4,(2,4,4))
# Out:
# array([[[2, 2, 1, 1],
#         [2, 1, 2, 2],
#         [1, 2, 2, 3],
#         [1, 2, 1, 3]],
#
#        [[1, 3, 1, 1],
#         [1, 3, 1, 3],
#         [3, 2, 1, 1],
#         [3, 2, 3, 2]]])

# %%
np.random.rand(3)
# Out:
# array([0.13145815, 0.41366737, 0.77872881])

# %%
np.random.rand(3,3)
# Out:
# array([[0.58390137, 0.18263144, 0.82608225],
#        [0.10540183, 0.28357668, 0.06556327],
#        [0.05644419, 0.76545582, 0.01178803]])

# %%
np.random.randn(3,3)
# Out:
# array([[-1.58494101,  1.05535316, -1.92657911],
#        [ 0.69858388, -0.74620143, -0.15662666],
#        [-0.19363594,  1.13912535,  0.36221796]])

# %%
x = [1,2,3,4]
np.random.choice(x)
# Out:
# 1

# %%
np.random.choice(x)
# Out:
# 1

# %%
for i in range(20):
    print(np.random.choice(x))
# Out:
# 1
# 2
# 1
# 4
# 1
# 1
# 3
# 1
# 3
# 3
# 1
# 4
# 2
# 1
# 4
# 2
# 3
# 3
# 2
# 3

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
np.random.permutation(x)
# Out:
# array([2, 4, 1, 3])

# %%
np.random.permutation(x)
# Out:
# array([2, 3, 4, 1])
