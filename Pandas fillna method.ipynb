# %%
import pandas as pd

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune_5.csv')
df
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet    NaN                  -2.8   Technology
# 3     4          McKesson    NaN                  11.2  Health Care
# 4     5           Cencora    NaN                   NaN   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9               NaN    NaN                   NaN          NaN
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                       NaN

# %%
df.fillna(2)
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   2.0    Retailing
# 2     3          Alphabet      2                  -2.8   Technology
# 3     4          McKesson      2                  11.2  Health Care
# 4     5           Cencora      2                   2.0   Financials
# 5     6  Costco Wholesale      2                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9                 2      2                   2.0            2
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                         2

# %%
df.fillna({'Company':'none','Ticker':0,'Sector':0})
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   NaN    Retailing
# 2     3          Alphabet      0                  -2.8   Technology
# 3     4          McKesson      0                  11.2  Health Care
# 4     5           Cencora      0                   NaN   Financials
# 5     6  Costco Wholesale      0                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9              none      0                   NaN            0
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                       NaN

# %%
df.fillna(method='ffill')
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                  32.8    Retailing
# 2     3          Alphabet    WMT                  -2.8   Technology
# 3     4          McKesson    WMT                  11.2  Health Care
# 4     5           Cencora    WMT                  11.2   Financials
# 5     6  Costco Wholesale    WMT                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9          Alphabet  GOOGL                  23.0   Technology
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8           Internet Services and Retailing

# %%
df.fillna(method='pad')
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                  32.8    Retailing
# 2     3          Alphabet    WMT                  -2.8   Technology
# 3     4          McKesson    WMT                  11.2  Health Care
# 4     5           Cencora    WMT                  11.2   Financials
# 5     6  Costco Wholesale    WMT                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9          Alphabet  GOOGL                  23.0   Technology
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8           Internet Services and Retailing

# %%
df.fillna(method='bfill')
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                  -2.8    Retailing
# 2     3          Alphabet    WMT                  -2.8   Technology
# 3     4          McKesson    WMT                  11.2  Health Care
# 4     5           Cencora    WMT                 101.1   Financials
# 5     6  Costco Wholesale    WMT                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9               NaN    NaN                   NaN          NaN
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                       NaN

# %%
df.fillna(method= 'ffill',axis=0)
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                  32.8    Retailing
# 2     3          Alphabet    WMT                  -2.8   Technology
# 3     4          McKesson    WMT                  11.2  Health Care
# 4     5           Cencora    WMT                  11.2   Financials
# 5     6  Costco Wholesale    WMT                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9          Alphabet  GOOGL                  23.0   Technology
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8           Internet Services and Retailing

# %%
df.fillna(method= 'ffill',axis=1)
# Out:
#   Rank           Company            Ticker ProfitsPercentChange       Sector  \
# 0    1           Walmart               WMT                 32.8    Retailing
# 1    2       Exxon Mobil               WMT                  WMT    Retailing
# 2    3          Alphabet          Alphabet                 -2.8   Technology
# 3    4          McKesson          McKesson                 11.2  Health Care
# 4    5           Cencora           Cencora              Cencora   Financials
# 5    6  Costco Wholesale  Costco Wholesale                101.1  Health Care
# 6    7       Exxon Mobil               WMT                -35.4       Energy
# 7    8          Alphabet             GOOGL                   23   Technology
# 8    9                 9                 9                    9            9
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                         9

# %%
df.fillna(method= 'bfill',axis=1)
# Out:
#   Rank           Company      Ticker ProfitsPercentChange       Sector  \
# 0    1           Walmart         WMT                 32.8    Retailing
# 1    2       Exxon Mobil         WMT            Retailing    Retailing
# 2    3          Alphabet        -2.8                 -2.8   Technology
# 3    4          McKesson        11.2                 11.2  Health Care
# 4    5           Cencora  Financials           Financials   Financials
# 5    6  Costco Wholesale       101.1                101.1  Health Care
# 6    7       Exxon Mobil         WMT                -35.4       Energy
# 7    8          Alphabet       GOOGL                   23   Technology
# 8    9               NaN         NaN                  NaN          NaN
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                       NaN

# %%
df.fillna(0, limit=2)
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   0.0    Retailing
# 2     3          Alphabet      0                  -2.8   Technology
# 3     4          McKesson      0                  11.2  Health Care
# 4     5           Cencora    NaN                   0.0   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9                 0    NaN                   NaN            0
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                         0

# %%
df.fillna(method='ffill', limit=2)
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                  32.8    Retailing
# 2     3          Alphabet    WMT                  -2.8   Technology
# 3     4          McKesson    WMT                  11.2  Health Care
# 4     5           Cencora    NaN                  11.2   Financials
# 5     6  Costco Wholesale    NaN                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9          Alphabet  GOOGL                  23.0   Technology
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8           Internet Services and Retailing

# %%
df.fillna(5,inplace=True)
df
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   5.0    Retailing
# 2     3          Alphabet      5                  -2.8   Technology
# 3     4          McKesson      5                  11.2  Health Care
# 4     5           Cencora      5                   5.0   Financials
# 5     6  Costco Wholesale      5                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9                 5      5                   5.0            5
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                         5

# %%
df
# Out:
#    Rank           Company Ticker  ProfitsPercentChange       Sector  \
# 0     1           Walmart    WMT                  32.8    Retailing
# 1     2       Exxon Mobil    WMT                   5.0    Retailing
# 2     3          Alphabet      5                  -2.8   Technology
# 3     4          McKesson      5                  11.2  Health Care
# 4     5           Cencora      5                   5.0   Financials
# 5     6  Costco Wholesale      5                 101.1  Health Care
# 6     7       Exxon Mobil    WMT                 -35.4       Energy
# 7     8          Alphabet  GOOGL                  23.0   Technology
# 8     9                 5      5                   5.0            5
#
#                                    Industry
# 0                     General Merchandisers
# 1           Internet Services and Retailing
# 2               Computers, Office Equipment
# 3   Health Care: Insurance and Managed Care
# 4  Insurance: Property and Casualty (Stock)
# 5  Health Care: Pharmacy and Other Services
# 6                        Petroleum Refining
# 7           Internet Services and Retailing
# 8                                         5
