# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
from matplotlib import style

# %%
plt.subplot(2,2,1)
plt.pie([1])
plt.subplot(2,2,2)
plt.pie([1,2])
plt.subplot(2,2,3)
plt.pie([1,2,3])
plt.subplot(2,2,4)
plt.pie([1,2,3,4])

plt.show()

# %%
plt.figure(figsize=(16,9))

#plt.subplot(3,2,1)
plt.subplot(321)
#*****************************

Days =[1,2,3,4,5,6,7,7,8,9]
Delhi_Temp =[23,56,78,23,67,89,56,78,90,20]
Mumbai_Temp = [45,78,13,89,90,12,34,17,53,94]

plt.plot(Days,Delhi_Temp,"mo--",linewidth =2,markersize = 5,
         label = "Delhi_Temp")
plt.plot(Days,Mumbai_Temp,"ro--",linewidth =2,markersize = 5,
         label ="Mumbai_Temp")
plt.title("Delhi& Mumbai Temperature",fontsize =15)
plt.xlabel("Days",fontsize =10)
plt.ylabel("Temp",fontsize =10)
plt.legend(loc =4)
plt.grid(color='k',linestyle = '-',linewidth=1)
#*************************************

plt.subplot(3,2,2)
#*********************************************
ml_student_age = np.random.randint(18,45,(100))
py_student_age = np.random.randint(15,40,(100))
bins = [15,20,25,30,35,40,45]

plt.hist([ml_student_age,py_student_age],bins,rwidth = 0.8,histtype ="bar",orientation = "vertical",
        color=['g','m'],label = ["ML Student","Py Student"])
#plt.hist(py_student_age,bins,rwidth = 0.8,histtype ="bar",orientation = "vertical",color='b',label = "Py Student")
plt.title("ML Students age histograms")
plt.xlabel("Student age category")
plt.ylabel("No. Student age")
plt.legend()
#***************************************************
plt.subplot(3,2,3)
#****************************************************
Classes = ["Python","R","AI","ML","DS"]
Class1_student = [30,10,20,25,10]
Class2_student = [40,5,20,20,10]
Class3_student = [35,5,30,15,14]

style.use("ggplot")

Classes_index = np.arange(len(Classes))

width=0.2
plt.bar(Classes_index,Class1_student,width,color = 'b',
        label="Class 1 student")

plt.bar(Classes_index+width,Class2_student,width,color = 'g',
        label="Class 2 student")

plt.bar(Classes_index+width+width,Class3_student,width,color = 'm',
        label="Class 3 student")

plt.xticks(Classes_index+width, Classes,rotation=10)
plt.title("Bar Chart of IAIP Class",fontsize = 18)
plt.xlabel("Classes",fontsize = 15)
plt.ylabel("No. of Student",fontsize = 15)
#**********************************************************
plt.subplot(3,2,4)
#**************************************************************
df=pd.read_csv("C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\googleplaystore.csv",nrows=1000)
x=df["Rating"]
y=df["Reviews"]
plt.scatter(x,y,c="r",s=100,alpha=0.5,linewidth=10,edgecolor='g')
plt.scatter(x,df["Installs"],c="b",s=100,alpha=0.5,linewidth=10,edgecolor='b')
plt.title("Google play store apps Scatter plot")
plt.xlabel("Rating")
plt.ylabel("Reviews and Install")
#*****************************************************
plt.subplot(3,2,5)
#****************************************************
classes=["Python",'R','Machine Learning',"Artificial Intelligence","Data Science"]
Class1_student =[45,15,35,25,30]
explode = [0,0.03,0.1,0,0]
colors=['c','b','r','y','g']

wedgeprops ={"linewidth":4,'width':3,"edgecolor":'k'}
textprops={"fontsize":15}
plt.pie(Class1_student,
        labels=classes,
        explode=explode,
        colors=colors, 
        autopct ="%0.2f%%",
        shadow=True,
        radius = 1.4,
        startangle = 270,
        textprops=textprops)
#********************************************************
plt.subplot(3,2,6,projection='polar',facecolor='k',frameon=True)

plt.show()
