# %%
import numpy as np

# %%
x =np.array([1,2,3,4])
print(x)
print(type(x))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>

# %%
x.size
# Out:
# 4

# %%
y=[1,2,3,4]
print(y)
print(type(y))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
# %timeit [j**4 for j in range(1,9)]
# Out:
# 7.1 µs ± 151 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit np.arange(1,9)**4
# Out:
# 5.35 µs ± 225 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# User defined array
l=[]

for i in range(1,5):
    int_1 = int(input("Enter :"))
    l.append(int_1)
    
print(np.array(l))
# Out:
# Enter :12
# Enter :34
# Enter :4
# Enter :5
# [12 34  4  5]

# %% [markdown]
# Types of array:
# 1D Array-[1,2,3,4]
# 2D Array-[[1,2,3,4]]
# 3D Array-[[[1,2,3,4]]]
# Higher Dimentional Array

# %%
x =np.array([1,2,3,4])
print(x)
print(type(x))
print(x.ndim)
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
# 1

# %%
ar2 = np.array([[1,2,3,4],[2,3,4,7]])
print(ar2)
print(ar2.ndim)
# Out:
# [[1 2 3 4]
#  [2 3 4 7]]
# 2

# %%
ar2.size
# Out:
# 8

# %%
ar2.shape  # (row,col)
# Out:
# (2, 4)

# %%
ar2.dtype
# Out:
# dtype('int32')

# %%
ar3 = np.array([[[1,2,3,4],[4,5,6,7],[6,7,8,9]]])
print(ar3)
print(ar3.ndim)
# Out:
# [[[1 2 3 4]
#   [4 5 6 7]
#   [6 7 8 9]]]
# 3

# %%
arn = np.array([1,2,3,4],ndmin =10)
print(arn)
print(arn.ndim)
# Out:
# [[[[[[[[[[1 2 3 4]]]]]]]]]]
# 10
