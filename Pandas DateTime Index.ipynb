# %%
import pandas as pd

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\VC_Student.csv')
df
# Out:
#      gener  Year  Budget  Rating%       Date
# 0   Action  2008      20       45  23-06-2024
# 1   Action  2010     200       67  24-07-2024
# 2   Action  2010      45       34  23-06-2025
# 3      ADV  2011      67       33  24-07-2025
# 4      ADV  2012      89       66  23-06-2026
# 5      ADV  2012      23       84  24-07-2026
# 6  Comedy   2012     456       21  23-06-2027
# 7  Comedy   2015      67       64  24-07-2027

# %%
df.dtypes
# Out:
# gener      object
# Year        int64
# Budget      int64
# Rating%     int64
# Date       object
# dtype: object

# %%
type(df.Date[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-894535e30701> in <module>
# ----> 1 type(df.Date[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Date'
