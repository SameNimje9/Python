# %%
import pandas as pd

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\student.csv')
df
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148           72.0             35        0  33.6
# 1             1       85           66.0             29        0  26.6
# 2             8      183           64.0              0        0  23.3
# 3             1       89            NaN             23       94  28.1
# 4             0      137            NaN             35      168  43.1
# 5             5      116            NaN              0        0  25.6
# 6             3       78            NaN             32       88  31.0
# 7            10      115            0.0              0        0  35.3
# 8             2      197           70.0             45      543  30.5
# 9             8      125           96.0              0        0   0.0
# 10            4      110           92.0              0        0  37.6
# 11           10      168           74.0              0        0  38.0
#
#           date
# 0   23-10-2025
# 1   23-10-2026
# ...

# %%
df.interpolate()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148           72.0             35        0  33.6
# 1             1       85           66.0             29        0  26.6
# 2             8      183           64.0              0        0  23.3
# 3             1       89           51.2             23       94  28.1
# 4             0      137           38.4             35      168  43.1
# 5             5      116           25.6              0        0  25.6
# 6             3       78           12.8             32       88  31.0
# 7            10      115            0.0              0        0  35.3
# 8             2      197           70.0             45      543  30.5
# 9             8      125           96.0              0        0   0.0
# 10            4      110           92.0              0        0  37.6
# 11           10      168           74.0              0        0  38.0
#
#           date
# 0   23-10-2025
# 1   23-10-2026
# ...

# %%
df.interpolate(method='linear')
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148           72.0             35        0  33.6
# 1             1       85           66.0             29        0  26.6
# 2             8      183           64.0              0        0  23.3
# 3             1       89           51.2             23       94  28.1
# 4             0      137           38.4             35      168  43.1
# 5             5      116           25.6              0        0  25.6
# 6             3       78           12.8             32       88  31.0
# 7            10      115            0.0              0        0  35.3
# 8             2      197           70.0             45      543  30.5
# 9             8      125           96.0              0        0   0.0
# 10            4      110           92.0              0        0  37.6
# 11           10      168           74.0              0        0  38.0
#
#           date
# 0   23-10-2025
# 1   23-10-2026
# ...

# %%
df.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b2b35dd0218a> in <module>
# ----> 1 df.interpolate(method='time')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6868                 "those NaNs before interpolating."
#    6869             )
# -> 6870         new_data = obj._mgr.interpolate(
#    6871             method=method,
#    6872             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     559
#     560     def interpolate(self, **kwargs) -> "BlockManager":
# --> 561         return self.apply("interpolate", **kwargs)
#     562
#     563     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ...

# %%
type(df.date[0])
# Out:
# str

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\student.csv',parse_dates=['date'])
df
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148           72.0             35        0  33.6
# 1             1       85           66.0             29        0  26.6
# 2             8      183           64.0              0        0  23.3
# 3             1       89            NaN             23       94  28.1
# 4             0      137            NaN             35      168  43.1
# 5             5      116            NaN              0        0  25.6
# 6             3       78            NaN             32       88  31.0
# 7            10      115            0.0              0        0  35.3
# 8             2      197           70.0             45      543  30.5
# 9             8      125           96.0              0        0   0.0
# 10            4      110           92.0              0        0  37.6
# 11           10      168           74.0              0        0  38.0
#
#          date
# 0  2025-10-23
# 1  2026-10-23
# ...

# %%
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\student.csv',parse_dates=['date'],index_col='date')
df
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89            NaN             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78            NaN             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(method='time')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148      72.000000             35        0  33.6
# 2026-10-23            1       85      66.000000             29        0  26.6
# 2027-10-23            8      183      64.000000              0        0  23.3
# 2028-10-23            1       89      51.178982             23       94  28.1
# 2029-10-23            0      137      38.392994             35      168  43.1
# 2030-10-23            5      116      25.607006              0        0  25.6
# 2031-10-23            3       78      12.821018             32       88  31.0
# 2032-10-23           10      115       0.000000              0        0  35.3
# 2033-10-23            2      197      70.000000             45      543  30.5
# 2034-10-23            8      125      96.000000              0        0   0.0
# 2035-10-23            4      110      92.000000              0        0  37.6
# ...

# %%
df.interpolate(method='index')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148      72.000000             35        0  33.6
# 2026-10-23            1       85      66.000000             29        0  26.6
# 2027-10-23            8      183      64.000000              0        0  23.3
# 2028-10-23            1       89      51.178982             23       94  28.1
# 2029-10-23            0      137      38.392994             35      168  43.1
# 2030-10-23            5      116      25.607006              0        0  25.6
# 2031-10-23            3       78      12.821018             32       88  31.0
# 2032-10-23           10      115       0.000000              0        0  35.3
# 2033-10-23            2      197      70.000000             45      543  30.5
# 2034-10-23            8      125      96.000000              0        0   0.0
# 2035-10-23            4      110      92.000000              0        0  37.6
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\student.csv',parse_dates=['date'],index_col='Pregnancies')
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI       date
# Pregnancies
# 6                148           72.0             35        0  33.6 2025-10-23
# 1                 85           66.0             29        0  26.6 2026-10-23
# 8                183           64.0              0        0  23.3 2027-10-23
# 1                 89            NaN             23       94  28.1 2028-10-23
# 0                137            NaN             35      168  43.1 2029-10-23
# 5                116            NaN              0        0  25.6 2030-10-23
# 3                 78            NaN             32       88  31.0 2031-10-23
# 10               115            0.0              0        0  35.3 2032-10-23
# 2                197           70.0             45      543  30.5 2033-10-23
# 8                125           96.0              0        0   0.0 2034-10-23
# 4                110           92.0              0        0  37.6 2035-10-23
# ...

# %%
df.interpolate(method='index')
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI       date
# Pregnancies
# 6                148           72.0             35        0  33.6 2025-10-23
# 1                 85           66.0             29        0  26.6 2026-10-23
# 8                183           64.0              0        0  23.3 2027-10-23
# 1                 89           66.0             23       94  28.1 2028-10-23
# 0                137           66.0             35      168  43.1 2029-10-23
# 5                116           82.0              0        0  25.6 2030-10-23
# 3                 78           81.0             32       88  31.0 2031-10-23
# 10               115            0.0              0        0  35.3 2032-10-23
# 2                197           70.0             45      543  30.5 2033-10-23
# 8                125           96.0              0        0   0.0 2034-10-23
# 4                110           92.0              0        0  37.6 2035-10-23
# ...

# %%
df.interpolate(method='nearest')
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI       date
# Pregnancies
# 6                148           72.0             35        0  33.6 2025-10-23
# 1                 85           66.0             29        0  26.6 2026-10-23
# 8                183           64.0              0        0  23.3 2027-10-23
# 1                 89           66.0             23       94  28.1 2028-10-23
# 0                137            NaN             35      168  43.1 2029-10-23
# 5                116           92.0              0        0  25.6 2030-10-23
# 3                 78           70.0             32       88  31.0 2031-10-23
# 10               115            0.0              0        0  35.3 2032-10-23
# 2                197           70.0             45      543  30.5 2033-10-23
# 8                125           96.0              0        0   0.0 2034-10-23
# 4                110           92.0              0        0  37.6 2035-10-23
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\student.csv',parse_dates=['date'],index_col='date')
df
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89            NaN             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78            NaN             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(method='polynomial',order=1)
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148      72.000000             35        0  33.6
# 2026-10-23            1       85      66.000000             29        0  26.6
# 2027-10-23            8      183      64.000000              0        0  23.3
# 2028-10-23            1       89      51.178982             23       94  28.1
# 2029-10-23            0      137      38.392994             35      168  43.1
# 2030-10-23            5      116      25.607006              0        0  25.6
# 2031-10-23            3       78      12.821018             32       88  31.0
# 2032-10-23           10      115       0.000000              0        0  35.3
# 2033-10-23            2      197      70.000000             45      543  30.5
# 2034-10-23            8      125      96.000000              0        0   0.0
# 2035-10-23            4      110      92.000000              0        0  37.6
# ...

# %%
df.interpolate(method='polynomial',order=2)
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148      72.000000             35        0  33.6
# 2026-10-23            1       85      66.000000             29        0  26.6
# 2027-10-23            8      183      64.000000              0        0  23.3
# 2028-10-23            1       89      47.318881             23       94  28.1
# 2029-10-23            0      137      12.945917             35      168  43.1
# 2030-10-23            5      116     -31.288782              0        0  25.6
# 2031-10-23            3       78     -38.276682             32       88  31.0
# 2032-10-23           10      115       0.000000              0        0  35.3
# 2033-10-23            2      197      70.000000             45      543  30.5
# 2034-10-23            8      125      96.000000              0        0   0.0
# 2035-10-23            4      110      92.000000              0        0  37.6
# ...

# %%
df.interpolate(method='spline',order=2)
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148      72.000000             35        0  33.6
# 2026-10-23            1       85      66.000000             29        0  26.6
# 2027-10-23            8      183      64.000000              0        0  23.3
# 2028-10-23            1       89      46.587137             23       94  28.1
# 2029-10-23            0      137      13.738687             35      168  43.1
# 2030-10-23            5      116     -27.883969              0        0  25.6
# 2031-10-23            3       78     -34.479445             32       88  31.0
# 2032-10-23           10      115       0.000000              0        0  35.3
# 2033-10-23            2      197      70.000000             45      543  30.5
# 2034-10-23            8      125      96.000000              0        0   0.0
# 2035-10-23            4      110      92.000000              0        0  37.6
# ...

# %%
df
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89            NaN             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78            NaN             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate()
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89           51.2             23       94  28.1
# 2029-10-23            0      137           38.4             35      168  43.1
# 2030-10-23            5      116           25.6              0        0  25.6
# 2031-10-23            3       78           12.8             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.dtypes
# Out:
# Pregnancies        int64
# Glucose            int64
# BloodPressure    float64
# SkinThickness      int64
# Insulin            int64
# BMI              float64
# dtype: object

# %%
df.interpolate(limit=1)
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89           51.2             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78            NaN             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(limit=2)
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89           51.2             23       94  28.1
# 2029-10-23            0      137           38.4             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78            NaN             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(limit=1,limit_direction='backward')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89            NaN             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78           12.8             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(limit=2,limit_direction='backward')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89            NaN             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116           25.6              0        0  25.6
# 2031-10-23            3       78           12.8             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(limit=1,limit_direction='both')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89           51.2             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78           12.8             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(limit_area='inside')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89           51.2             23       94  28.1
# 2029-10-23            0      137           38.4             35      168  43.1
# 2030-10-23            5      116           25.6              0        0  25.6
# 2031-10-23            3       78           12.8             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(limit_area='outside')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89            NaN             23       94  28.1
# 2029-10-23            0      137            NaN             35      168  43.1
# 2030-10-23            5      116            NaN              0        0  25.6
# 2031-10-23            3       78            NaN             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...

# %%
df.interpolate(inplace=True)
df
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# date
# 2025-10-23            6      148           72.0             35        0  33.6
# 2026-10-23            1       85           66.0             29        0  26.6
# 2027-10-23            8      183           64.0              0        0  23.3
# 2028-10-23            1       89           51.2             23       94  28.1
# 2029-10-23            0      137           38.4             35      168  43.1
# 2030-10-23            5      116           25.6              0        0  25.6
# 2031-10-23            3       78           12.8             32       88  31.0
# 2032-10-23           10      115            0.0              0        0  35.3
# 2033-10-23            2      197           70.0             45      543  30.5
# 2034-10-23            8      125           96.0              0        0   0.0
# 2035-10-23            4      110           92.0              0        0  37.6
# ...
