# %%
#na_values
#keep_default_na
#na_filter

# %%
import pandas as pd

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
df
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                           NaN   AMZN            Retailing
# 2       3                 not available    NaN           Technology
# 3       4                           NaN    UNH          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',na_values =["not available",'No value'])
df
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                           NaN   AMZN            Retailing
# 2       3                           NaN    NaN           Technology
# 3       4                           NaN    UNH          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
df
# Out:
#      Rank                       Company         Ticker               Sector  \
# 0       1                       Walmart            WMT            Retailing
# 1       2                      No value           AMZN            Retailing
# 2       3                 not available            NaN           Technology
# 3       4                           NaN  not available          Health Care
# 4       5            Berkshire Hathaway           BRKA           Financials
# ..    ...                           ...            ...                  ...
# 995   996              Allegiant Travel           ALGT       Transportation
# 996   997                       Dropbox            DBX           Technology
# 997   998                Exact Sciences           EXAS          Health Care
# 998   999              BWX Technologies           BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.            CCO    Business Services
#
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',na_values ={'Company':'No value','Ticker':'not available'})
df
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                           NaN   AMZN            Retailing
# 2       3                 not available    NaN           Technology
# 3       4                           NaN    NaN          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
df.head(10)
# Out:
#    Rank             Company         Ticker       Sector  \
# 0     1             Walmart            WMT    Retailing
# 1     2            No value           AMZN    Retailing
# 2     3       not available            NaN   Technology
# 3     4                 NaN  not available  Health Care
# 4     5  Berkshire Hathaway            NaN   Financials
# 5     6          CVS Health            NaN  Health Care
# 6     7         Exxon Mobil            NaN       Energy
# 7     8            Alphabet          GOOGL   Technology
# 8     9            McKesson            MCK  Health Care
# 9    10             Cencora            COR  Health Care
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',keep_default_na = True)
df.head(10)
# Out:
#    Rank             Company         Ticker       Sector  \
# 0     1             Walmart            WMT    Retailing
# 1     2            No value           AMZN    Retailing
# 2     3       not available            NaN   Technology
# 3     4                 NaN  not available  Health Care
# 4     5  Berkshire Hathaway            NaN   Financials
# 5     6          CVS Health            NaN  Health Care
# 6     7         Exxon Mobil            NaN       Energy
# 7     8            Alphabet          GOOGL   Technology
# 8     9            McKesson            MCK  Health Care
# 9    10             Cencora            COR  Health Care
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
df.head(10)
# Out:
#    Rank      Company Ticker       Sector  \
# 0     1      Walmart    WMT    Retailing
# 1     2      Walmart    WMT    Retailing
# 2     3      Walmart    WMT   Technology
# 3     4      Walmart    WMT  Health Care
# 4     5      Walmart    WMT   Financials
# 5     6      Walmart    WMT  Health Care
# 6     7  Exxon Mobil    WMT       Energy
# 7     8     Alphabet  GOOGL   Technology
# 8     9     McKesson    MCK  Health Care
# 9    10      Cencora    COR  Health Care
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# 3   Health Care: Insurance and Managed Care        yes             no
# 4  Insurance: Property and Casualty (Stock)        yes             no
# 5  Health Care: Pharmacy and Other Services        yes             no
# ...

# %%
df =pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',na_filter= True)
df.head(10)
# Out:
#    Rank      Company Ticker       Sector  \
# 0     1      Walmart    WMT    Retailing
# 1     2      Walmart    WMT    Retailing
# 2     3      Walmart    WMT   Technology
# 3     4      Walmart    WMT  Health Care
# 4     5      Walmart    WMT   Financials
# 5     6      Walmart    WMT  Health Care
# 6     7  Exxon Mobil    WMT       Energy
# 7     8     Alphabet  GOOGL   Technology
# 8     9     McKesson    MCK  Health Care
# 9    10      Cencora    COR  Health Care
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# 3   Health Care: Insurance and Managed Care        yes             no
# 4  Insurance: Property and Casualty (Stock)        yes             no
# 5  Health Care: Pharmacy and Other Services        yes             no
# ...
