# %%
import pandas as pd

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
# Out:
#          1                             2       3                    4  \
# 0     Rank                       Company  Ticker               Sector
# 1        1                       Walmart     WMT            Retailing
# 2        2                        Amazon    AMZN            Retailing
# 3        3                         Apple    AAPL           Technology
# 4        4            UnitedHealth Group     UNH          Health Care
# ...    ...                           ...     ...                  ...
# 996    996              Allegiant Travel    ALGT       Transportation
# 997    997                       Dropbox     DBX           Technology
# 998    998                Exact Sciences    EXAS          Health Care
# 999    999              BWX Technologies    BWXT  Aerospace & Defense
# 1000  1000  Clear Channel Outdoor Hldgs.     CCO    Business Services
#
#                                             5           6               7  \
# ...

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv', header=1)
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                        Amazon   AMZN            Retailing
# 2       3                         Apple   AAPL           Technology
# 3       4            UnitedHealth Group    UNH          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
# Out:
#      Unnamed: 0                          Data Unnamed: 2           Unnamed: 3  \
# 0             1                             2          3                    4
# 1          Rank                       Company     Ticker               Sector
# 2             1                       Walmart        WMT            Retailing
# 3             2                        Amazon       AMZN            Retailing
# 4             3                         Apple       AAPL           Technology
# ...         ...                           ...        ...                  ...
# 997         996              Allegiant Travel       ALGT       Transportation
# 998         997                       Dropbox        DBX           Technology
# 999         998                Exact Sciences       EXAS          Health Care
# 1000        999              BWX Technologies       BWXT  Aerospace & Defense
# 1001       1000  Clear Channel Outdoor Hldgs.        CCO    Business Services
#
# ...

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',header=2)
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                        Amazon   AMZN            Retailing
# 2       3                         Apple   AAPL           Technology
# 3       4            UnitedHealth Group    UNH          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv')
# Out:
#         1                       Walmart   WMT            Retailing  \
# 0       2                        Amazon  AMZN            Retailing
# 1       3                         Apple  AAPL           Technology
# 2       4            UnitedHealth Group   UNH          Health Care
# 3       5            Berkshire Hathaway  BRKA           Financials
# 4       6                    CVS Health   CVS          Health Care
# ..    ...                           ...   ...                  ...
# 994   996              Allegiant Travel  ALGT       Transportation
# 995   997                       Dropbox   DBX           Technology
# 996   998                Exact Sciences  EXAS          Health Care
# 997   999              BWX Technologies  BWXT  Aerospace & Defense
# 998  1000  Clear Channel Outdoor Hldgs.   CCO    Business Services
#
#                         General Merchandisers  yes   no no.1 no.2   0  ...  \
# 0             Internet Services and Retailing  yes   no   no   no   0  ...
# ...

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',header=None)
# Out:
#        0                             1     2                    3   \
# 0       1                       Walmart   WMT            Retailing
# 1       2                        Amazon  AMZN            Retailing
# 2       3                         Apple  AAPL           Technology
# 3       4            UnitedHealth Group   UNH          Health Care
# 4       5            Berkshire Hathaway  BRKA           Financials
# ..    ...                           ...   ...                  ...
# 995   996              Allegiant Travel  ALGT       Transportation
# 996   997                       Dropbox   DBX           Technology
# 997   998                Exact Sciences  EXAS          Health Care
# 998   999              BWX Technologies  BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.   CCO    Business Services
#
#                                            4    5    6   7    8   9   ...  \
# 0                       General Merchandisers  yes   no  no   no   0  ...
# ...

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',header=None,prefix='Columns')
# Out:
#      Columns0                      Columns1 Columns2             Columns3  \
# 0           1                       Walmart      WMT            Retailing
# 1           2                        Amazon     AMZN            Retailing
# 2           3                         Apple     AAPL           Technology
# 3           4            UnitedHealth Group      UNH          Health Care
# 4           5            Berkshire Hathaway     BRKA           Financials
# ..        ...                           ...      ...                  ...
# 995       996              Allegiant Travel     ALGT       Transportation
# 996       997                       Dropbox      DBX           Technology
# 997       998                Exact Sciences     EXAS          Health Care
# 998       999              BWX Technologies     BWXT  Aerospace & Defense
# 999      1000  Clear Channel Outdoor Hldgs.      CCO    Business Services
#
#                                      Columns4 Columns5 Columns6 Columns7  \
# ...

# %%
pd.read_csv('C:\\Users\\NIMJESX\\Documents\\My Folder\\ML Notes\\Excel-Dataset\\fortune.csv',names =['a','b'])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                          a  \
# 1    Walmart                      WMT  Retailing           General Merchandisers                    yes no  no no   0  no  no  no  yes yes yes 2100000 484852.8  648125.0  6.0   15511.0  32.8   252399.0  C. Douglas McMillon      U.S. Bentonville   Arkansas   https://www.stock.walmart.com       Public Figures are for fiscal year ended Jan. 31, 2024...   559911.0
# ...
